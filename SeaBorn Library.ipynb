# %% [markdown]
# <a href="https://colab.research.google.com/github/Utkarshmishra2k2/Desideratum-Of-SeaBorn/blob/main/SeaBorn%20Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SeaBorn

# %%
import seaborn as sns    
import pandas as pd     
import numpy as np

# %%
# !ls -lh
# Out:
# total 4.0K
# drwxr-xr-x 1 root root 4.0K Sep 26 13:45 sample_data

# %%
df01=sns.load_dataset('planets')

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df01.info
# Out:
# <bound method DataFrame.info of                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]>

# %%
df01.head(30)
# Out:
#              method  number  orbital_period    mass  distance  year
# 0   Radial Velocity       1      269.300000   7.100     77.40  2006
# 1   Radial Velocity       1      874.774000   2.210     56.95  2008
# 2   Radial Velocity       1      763.000000   2.600     19.84  2011
# 3   Radial Velocity       1      326.030000  19.400    110.62  2007
# 4   Radial Velocity       1      516.220000  10.500    119.47  2009
# 5   Radial Velocity       1      185.840000   4.800     76.39  2008
# 6   Radial Velocity       1     1773.400000   4.640     18.15  2002
# 7   Radial Velocity       1      798.500000     NaN     21.41  1996
# 8   Radial Velocity       1      993.300000  10.300     73.10  2008
# 9   Radial Velocity       2      452.800000   1.990     74.79  2010
# 10  Radial Velocity       2      883.000000   0.860     74.79  2010
# 11  Radial Velocity       1      335.100000   9.880     39.43  2009
# 12  Radial Velocity       1      479.100000   3.880     97.28  2008
# ...

# %%
df01.tail(30)
# Out:
#        method  number  orbital_period  mass  distance  year
# 1005  Transit       1        3.693641   NaN     200.0  2012
# 1006  Transit       1        4.465633   NaN     330.0  2012
# 1007  Transit       1        4.617101   NaN     255.0  2012
# 1008  Transit       1        2.838971   NaN     455.0  2012
# 1009  Transit       1        5.017180   NaN     300.0  2012
# 1010  Transit       1        7.919585   NaN     125.0  2012
# 1011  Transit       1        4.305001   NaN     400.0  2012
# 1012  Transit       1        3.855900   NaN     480.0  2012
# 1013  Transit       1        4.411953   NaN     160.0  2012
# 1014  Transit       1        4.378090   NaN     330.0  2012
# 1015  Transit       1        1.573292   NaN     350.0  2012
# 1016  Transit       1        2.311424   NaN     310.0  2013
# 1017  Transit       1        4.086052   NaN     380.0  2012
# 1018  Transit       1        4.614420   NaN     225.0  2012
# 1019  Transit       1        2.903675   NaN     345.0  2012
# ...

# %%
df01.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %% [markdown]
# Go Through The Each Row And Delete  Null Values
#
# -Hind: Use Drop Function

# %%
#Here I Doing By Iterative Way
for row in df01.index:                             
    for column in df01.columns:                       
        if pd.isnull(df01.loc[row,column]):         
            df01.drop(row,inplace=True)              
            break

# %%
df01.describe()
# Out:
#           number  orbital_period        mass    distance         year
# count  498.00000      498.000000  498.000000  498.000000   498.000000
# mean     1.73494      835.778671    2.509320   52.068213  2007.377510
# std      1.17572     1469.128259    3.636274   46.596041     4.167284
# min      1.00000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.00000       38.272250    0.212500   24.497500  2005.000000
# 50%      1.00000      357.000000    1.245000   39.940000  2009.000000
# 75%      2.00000      999.600000    2.867500   59.332500  2011.000000
# max      6.00000    17337.500000   25.000000  354.000000  2014.000000

# %%
#Here I Doing By Non-Iterative Way
df01.dropna(inplace=True)          
df01.describe()
# Out:
#           number  orbital_period        mass    distance         year
# count  498.00000      498.000000  498.000000  498.000000   498.000000
# mean     1.73494      835.778671    2.509320   52.068213  2007.377510
# std      1.17572     1469.128259    3.636274   46.596041     4.167284
# min      1.00000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.00000       38.272250    0.212500   24.497500  2005.000000
# 50%      1.00000      357.000000    1.245000   39.940000  2009.000000
# 75%      2.00000      999.600000    2.867500   59.332500  2011.000000
# max      6.00000    17337.500000   25.000000  354.000000  2014.000000

# %%
#Here I Doing By Iterative Way
for i,r in df01.iterrows():
    if pd.isnull(r).any():
        df.drop(i,inplace=True)

# %%
df01.describe()
# Out:
#           number  orbital_period        mass    distance         year
# count  498.00000      498.000000  498.000000  498.000000   498.000000
# mean     1.73494      835.778671    2.509320   52.068213  2007.377510
# std      1.17572     1469.128259    3.636274   46.596041     4.167284
# min      1.00000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.00000       38.272250    0.212500   24.497500  2005.000000
# 50%      1.00000      357.000000    1.245000   39.940000  2009.000000
# 75%      2.00000      999.600000    2.867500   59.332500  2011.000000
# max      6.00000    17337.500000   25.000000  354.000000  2014.000000

# %% [markdown]
# **Querying Data Base**

# %% [markdown]
# Filter And Shiw Only Those Rows Which Have Planets That Are Found in The 2000s and methos is "Radial Velocity" and "Transit" is large(>60 Percentile)

# %%
#Here Doing By Inefficient Way
df0101=df01.copy()                                                        
for i,r in df0101.iterrows():                                            
    if r["year"]<2000:                                                    
        df0101.drop(i,inplace=True)                                     
        continue                                                          
    if r["method"]!="Radial Velocity" and r["method"]!="Transit":        
        df0101.drop(i,inplace=True)                                      
        continue                                                        
    if r["distance"]<df01.distance.quantile(0.60):                        
        df0101.drop(i,inplace=True)                                       
        continue

# %%
df0101.describe()
# Out:
#            number  orbital_period        mass    distance         year
# count  196.000000      196.000000  196.000000  196.000000   196.000000
# mean     1.326531      792.345379    3.339158   90.476582  2008.408163
# std      0.595289      931.765439    3.773461   53.369688     2.957257
# min      1.000000        2.137500    0.027000   47.260000  2001.000000
# 25%      1.000000      176.907500    0.982500   54.590000  2007.000000
# 50%      1.000000      465.550000    1.950000   68.565000  2009.000000
# 75%      2.000000     1000.475000    3.880000  110.620000  2011.000000
# max      3.000000     5584.000000   20.600000  354.000000  2014.000000

# %%
#Here I Have Doing By Writing Logical Way
df0101=df0101[                                                                
       (df0101["year"]>=2000)&
       (df0101["method"]=="Radial Velocity") | (df0101["method"]=="Transit")&
       (df0101["distance"]>df0101.distance.quantile(0.65))
]

# %%
df0101.describe()
# Out:
#            number  orbital_period        mass    distance         year
# count  196.000000      196.000000  196.000000  196.000000   196.000000
# mean     1.326531      792.345379    3.339158   90.476582  2008.408163
# std      0.595289      931.765439    3.773461   53.369688     2.957257
# min      1.000000        2.137500    0.027000   47.260000  2001.000000
# 25%      1.000000      176.907500    0.982500   54.590000  2007.000000
# 50%      1.000000      465.550000    1.950000   68.565000  2009.000000
# 75%      2.000000     1000.475000    3.880000  110.620000  2011.000000
# max      3.000000     5584.000000   20.600000  354.000000  2014.000000

# %% [markdown]
# Modify the method Column to Have Only The Abbreviation of Each Method

# %%
df02=sns.load_dataset('planets')

# %%
df02.method.unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %% [markdown]
# Count The Number of Planet Discovered For each Method Type

# %% [markdown]
# Steps To Do Such Problem
#
# *   **Split**-Split The dataFrame Into Smaller Chunks
# *   **Apply Function**-Apply Some Function In Each Chunks
# *   **Aggregate Result**- Aggregate The Results From Each Chunk Together

# %%
##Here I'm Doing By Iterative Way
Dictionary01={}                       
for Method in df02.method.unique():    
    Dictionary01[Method]=df02[df02.method==Method]["method"].count()   
print(Dictionary01)
# Out:
# {'Radial Velocity': 553, 'Imaging': 38, 'Eclipse Timing Variations': 9, 'Transit': 397, 'Astrometry': 2, 'Transit Timing Variations': 4, 'Orbital Brightness Modulation': 3, 'Microlensing': 23, 'Pulsar Timing': 5, 'Pulsation Timing Variations': 1}

# %%
#Here I'm Doing By Non-Iterative way
df02.groupby("method")["method"].count()
# Out:
# method
# Astrometry                         2
# Eclipse Timing Variations          9
# Imaging                           38
# Microlensing                      23
# Orbital Brightness Modulation      3
# Pulsar Timing                      5
# Pulsation Timing Variations        1
# Radial Velocity                  553
# Transit                          397
# Transit Timing Variations          4
# Name: method, dtype: int64

# %%
#Similar Example
df02.groupby("method")["mass"].median()
# Out:
# method
# Astrometry                         NaN
# Eclipse Timing Variations        5.125
# Imaging                            NaN
# Microlensing                       NaN
# Orbital Brightness Modulation      NaN
# Pulsar Timing                      NaN
# Pulsation Timing Variations        NaN
# Radial Velocity                  1.260
# Transit                          1.470
# Transit Timing Variations          NaN
# Name: mass, dtype: float64

# %% [markdown]
# Find Out What Fraction Of Planets have Found In Last Two Decade(i.e in 2000's) across each method type

# %% [markdown]
# Steps To Solve The Such Problem
#
#
#
# *   **Filter**-Filter the Data According To Given Condition
# *   **Split**-Split The Data
# *   **Apply**-Apply The Conditions
# *   **Aggregate**-Aggregate The Data Frame

# %%
#Here I'm Doing By Non Iterative Way
df02[df02.year>=2000].groupby("method")["method"].count()
# Out:
# method
# Astrometry                         2
# Eclipse Timing Variations          9
# Imaging                           38
# Microlensing                      23
# Orbital Brightness Modulation      3
# Pulsar Timing                      2
# Pulsation Timing Variations        1
# Radial Velocity                  524
# Transit                          397
# Transit Timing Variations          4
# Name: method, dtype: int64

# %%
#Here New DataFrame[Filtering].Sent To Grouping(Grouping By This).[Sent To The Subset].Applying The Function()

# %%
TimeLineAll=df02.groupby("method")["method"].count()        
TimeLine2000=df02[df02.year>=2000].groupby("method")["method"].count()

# %%
TimeLine2000/TimeLineAll
# Out:
# method
# Astrometry                       1.000000
# Eclipse Timing Variations        1.000000
# Imaging                          1.000000
# Microlensing                     1.000000
# Orbital Brightness Modulation    1.000000
# Pulsar Timing                    0.400000
# Pulsation Timing Variations      1.000000
# Radial Velocity                  0.947559
# Transit                          1.000000
# Transit Timing Variations        1.000000
# Name: method, dtype: float64

# %% [markdown]
# File Handling

# %%
File01=pd.read_csv("https://raw.githubusercontent.com/UM1412/Data-Set/main/SeaBourne-Nifty.csv")

# %%
File01.head(25)
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0     NIFTY 50  18,080.60  18,095.45  17,921.55      18,053.40  17,957.40
# 1   ADANIPORTS     840.00     860.90     826.00         818.55     844.05
# 2         NTPC     145.40     150.60     144.75         144.30     148.40
# 3   TATAMOTORS     450.00     461.90     448.30         446.75     457.30
# 4    POWERGRID     229.95     234.60     226.90         227.40     232.40
# 5   TATACONSUM     791.00     810.00     788.20         788.10     804.00
# 6         ONGC     170.25     172.75     169.30         168.05     171.35
# 7    EICHERMOT   2,525.00   2,600.00   2,510.00       2,508.95   2,550.00
# 8          ITC     256.05     261.85     255.10         255.45     259.00
# 9       GRASIM   1,688.00   1,712.00   1,669.55       1,679.70   1,702.60
# 10         UPL     791.95     800.65     790.30         784.35     795.00
# 11    SHREECEM  24,720.00  25,270.00  24,682.50      24,765.05  25,100.00
# ...

# %%
File02=pd.read_csv("https://raw.githubusercontent.com/UM1412/Data-Set/main/SeaBourne-NiftyNext.csv",index_col=0)    
File02.head()
# Out:
#                  OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# SYMBOL \n
# NIFTY NEXT 50  42,628.20  43,000.05  42,453.25      42,403.90  42,753.25
# HAVELLS         1,187.00   1,264.95   1,183.60       1,180.30   1,257.00
# BAJAJHLDNG      6,010.45   6,598.00   5,951.00       5,828.45   6,150.00
# ADANIGREEN      2,152.70   2,209.95   2,122.00       2,110.45   2,192.00
# ADANIENT        2,078.00   2,189.80   2,067.60       2,065.85   2,131.00
#
#                CHNG \n  %CHNG \n  VOLUME \n(shares)              VALUE   \
# SYMBOL \n
# NIFTY NEXT 50   349.35      0.82          290748619  127,908,533,139.26
# HAVELLS          76.70      6.50            3238425    4,027,143,408.75
# BAJAJHLDNG      321.55      5.52             793218    4,904,220,996.42
# ADANIGREEN       81.55      3.86            2206673    4,800,992,245.91
# ADANIENT         65.15      3.15            4970260   10,614,984,282.00
#
#                 52W H \n   52W L \n 365 D % CHNG \n 01-Apr-2021  \
# ...

# %%
File02.loc["TATAMOTORS"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TATAMOTORS'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
File02["HIGH \n"]
# Out:
# SYMBOL \n
# NIFTY NEXT 50    43,000.05
# HAVELLS           1,264.95
# BAJAJHLDNG        6,598.00
# ADANIGREEN        2,209.95
# ADANIENT          2,189.80
# SRF               2,755.65
# MCDOWELL-N          937.65
# MARICO              547.85
# AMBUJACEM           317.70
# DLF                 396.60
# MINDTREE          4,429.00
# COLPAL            1,589.00
# PIIND             2,938.70
# ACC               2,158.00
# LTI               6,430.00
# DABUR               553.00
# CHOLAFIN            714.90
# NAUKRI            4,805.00
# JUBLFOOD          2,851.95
# PGHH             14,440.00
# ZYDUSLIFE           369.80
# PIDILITIND        2,527.15
# MUTHOOTFIN        1,374.00
# SIEMENS           2,463.10
# PNB                  37.50
# BOSCHLTD         15,085.00
# IOC                 123.50
# BERGEPAINT          728.65
# BIOCON              350.00
# ICICIGI           1,359.15
# DMART             4,148.00
# GLAND             3,394.00
# GODREJCP            784.40
# ICICIPRULI          512.00
# ...

# %%
File03=pd.read_csv("https://raw.githubusercontent.com/UM1412/Data-Set/main/SeaBourne-NiftyNext.csv",index_col=0)   
File03.head()
# Out:
#                  OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# SYMBOL \n
# NIFTY NEXT 50  42,628.20  43,000.05  42,453.25      42,403.90  42,753.25
# HAVELLS         1,187.00   1,264.95   1,183.60       1,180.30   1,257.00
# BAJAJHLDNG      6,010.45   6,598.00   5,951.00       5,828.45   6,150.00
# ADANIGREEN      2,152.70   2,209.95   2,122.00       2,110.45   2,192.00
# ADANIENT        2,078.00   2,189.80   2,067.60       2,065.85   2,131.00
#
#                CHNG \n  %CHNG \n  VOLUME \n(shares)              VALUE   \
# SYMBOL \n
# NIFTY NEXT 50   349.35      0.82          290748619  127,908,533,139.26
# HAVELLS          76.70      6.50            3238425    4,027,143,408.75
# BAJAJHLDNG      321.55      5.52             793218    4,904,220,996.42
# ADANIGREEN       81.55      3.86            2206673    4,800,992,245.91
# ADANIENT         65.15      3.15            4970260   10,614,984,282.00
#
#                 52W H \n   52W L \n 365 D % CHNG \n 01-Apr-2021  \
# ...

# %% [markdown]
# Combining Data Frame

# %%
File02.shape,File03.shape
# Out:
# ((51, 13), (51, 13))

# %%
pd.concat([File02,File03])
# Out:
#                  OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# SYMBOL \n
# NIFTY NEXT 50  42,628.20  43,000.05  42,453.25      42,403.90  42,753.25
# HAVELLS         1,187.00   1,264.95   1,183.60       1,180.30   1,257.00
# BAJAJHLDNG      6,010.45   6,598.00   5,951.00       5,828.45   6,150.00
# ADANIGREEN      2,152.70   2,209.95   2,122.00       2,110.45   2,192.00
# ADANIENT        2,078.00   2,189.80   2,067.60       2,065.85   2,131.00
# ...                  ...        ...        ...            ...        ...
# TORNTPHARM      2,850.00   2,850.00   2,780.05       2,830.65   2,784.15
# ADANITRANS      2,457.00   2,515.00   2,382.20       2,453.50   2,410.00
# LUPIN             794.50     795.50     770.60         790.55     772.05
# ZOMATO             83.00      85.15      82.35          86.25      83.75
# SBICARD           859.00     864.95     836.00         876.15     839.90
#
#                CHNG \n  %CHNG \n  VOLUME \n(shares)              VALUE   \
# ...

# %%
pd.concat([File02,File03]).shape
# Out:
# (102, 13)

# %%
#pd.concat([File02,File03],axis=0) 
#Here It Is Not Working Because The Index Are Not same

# %% [markdown]
# Hierarchical Indexing

# %%
pd.concat([File02,File03],axis=0,keys=["SeaBourne-Nifty.csv","SeaBourne-NiftyNext.csv"])     #Here I Gave Hierarchical Index (i.e Separate Index To Separate File Index)
# Out:
#                                          OPEN \n    HIGH \n     LOW \n  \
#                         SYMBOL \n
# SeaBourne-Nifty.csv     NIFTY NEXT 50  42,628.20  43,000.05  42,453.25
#                         HAVELLS         1,187.00   1,264.95   1,183.60
#                         BAJAJHLDNG      6,010.45   6,598.00   5,951.00
#                         ADANIGREEN      2,152.70   2,209.95   2,122.00
#                         ADANIENT        2,078.00   2,189.80   2,067.60
# ...                                          ...        ...        ...
# SeaBourne-NiftyNext.csv TORNTPHARM      2,850.00   2,850.00   2,780.05
#                         ADANITRANS      2,457.00   2,515.00   2,382.20
#                         LUPIN             794.50     795.50     770.60
#                         ZOMATO             83.00      85.15      82.35
#                         SBICARD           859.00     864.95     836.00
#
#                                       PREV. CLOSE \n     LTP \n  CHNG \n  \
# ...
